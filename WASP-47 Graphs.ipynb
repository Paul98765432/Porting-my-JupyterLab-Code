# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import os
#os.listdir()   # Show me what is in the directory

# %%
# gonna write my thoughts here: I need to import the flux (column 1/2) 
# as the y axis and the BJD (column 0/1) as the x axis. I have no idea
# how to do this. I could refer to

# %%
data_planet = pd.read_excel("ep206103150.xlsx")

# %%
data_planet.head()
# Out:
#           time      flux       time.1
# 0  2146.452489  1.000454  2146.452489
# 1  2146.513785  1.000300  2146.513785
# 2  2146.534218  1.000206  2146.534218
# 3  2146.554650  1.000196  2146.554650
# 4  2146.575082  1.000163  2146.575082

# %%
plt.figure(figsize=(10,7))   # Set the size of your plot. It will determine the relative size of all the labels.
plt.plot(data_planet['time'],data_planet['flux'],label="Blue Led") # Plot a curve.
plt.xlabel("Time")
plt.ylabel("Flux")
plt.title("A real graph")
plt.show()

# %%
plt.figure(figsize=(10,7))   # Set the size of your plot. It will determine the relative size of all the labels.
plt.plot(data_planet['time'],data_planet['flux'],label="Blue Led") # Plot a curve.
plt.xlabel("Time")
plt.ylabel("Flux")
plt.title("A real graph")
# plt.xlim(2149, 2151) ignore this, likely is useless but don't want to remove it in case it is actually useful
plt.xlim(0, 8)
plt.plot(x % (572), y, '.')
plt.show()
