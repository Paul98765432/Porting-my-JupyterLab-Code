# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
# Disclaimer: Most of this is unoriginal and ripped directly from a random online tutorial.

# %%
data_planet = pd.read_excel("ep206103150.xlsx")

# %%
# data_planet.head()

# %%
plt.plot(data_planet['time'],data_planet['flux'],label="Blue Led") # Plot a curve.
plt.xlabel("Time")
plt.ylabel("Flux")
plt.title("A real graph")
plt.show()

# %%
plt.plot(data_planet['time'],data_planet['flux'])
plt.xlim(2149, 2151)
plt.xlabel("Time")
plt.ylabel("Flux")
plt.show()

# %%
plt.plot(data_planet['time'],data_planet['flux']) 
plt.xlim(2151, 2160)
plt.xlabel("Time")
plt.ylabel("Flux")
plt.show()

# %%
plt.plot(data_planet['time'],data_planet['flux']) 
plt.xlim(2161, 2170)
plt.xlabel("Time")
plt.ylabel("Flux")
plt.show()

# %%
plt.plot(data_planet['time'],data_planet['flux']) 
plt.xlim(2171, 2180)
plt.xlabel("Time")
plt.ylabel("Flux")
plt.show()

# %%
plt.plot(data_planet['time'],data_planet['flux']) 
plt.xlim(2181, 2190)
plt.xlabel("Time")
plt.ylabel("Flux")
plt.show()

# %%
plt.plot(data_planet['time'],data_planet['flux']) 
plt.xlim(2191, 2200)
plt.xlabel("Time")
plt.ylabel("Flux")
plt.show()

# %%
plt.plot(data_planet['time'],data_planet['flux']) 
plt.xlim(2201, 2210)
plt.xlabel("Time")
plt.ylabel("Flux")
plt.show()

# %%
plt.plot(data_planet['time'],data_planet['flux']) 
plt.xlim(2211, 2220)
plt.xlabel("Time")
plt.ylabel("Flux")
plt.show()

# %%
# Importing libraries
import matplotlib.pyplot as plt
import numpy as np
import math
  
# Using Numpy to create an array X
TimeEdit = np.arange(0, 4.1591, 0.05)
  
# Assign variables to the y axis part of the curve
a = plt.xlim(2149, 2151)
b = plt.xlim(2154.3, 2155)
c = plt.xlim(2158, 2158.6)
d = plt.xlim(2163, 2164)
e = plt.xlim(2166, 2167)
f = plt.xlim(2174.7, 2175)
g = plt.xlim(2183, 2183.4)
h = plt.xlim(2187, 2188)
i = plt.xlim(2191, 2192)
j = plt.xlim(2195.5, 2196)
k = plt.xlim(2199, 2200)
l = plt.xlim(2203.7, 2204.3)
m = plt.xlim(2208, 2208.5)
n = plt.xlim(2212, 2213)
# Plotting both the curves simultaneously
plt.plot(TimeEdit, a)
plt.plot(TimeEdit, b)
plt.plot(TimeEdit, c)
plt.plot(TimeEdit, d)
plt.plot(TimeEdit, e)
plt.plot(TimeEdit, f)
plt.plot(TimeEdit, g)
plt.plot(TimeEdit, h)
plt.plot(TimeEdit, i)
plt.plot(TimeEdit, j)
plt.plot(TimeEdit, k)
plt.plot(TimeEdit, l)
plt.plot(TimeEdit, m)
plt.plot(TimeEdit, n)
  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Orbital Period")
plt.ylabel("Flux")
plt.title("Functioning Graph?")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 25
#      23 n = plt.xlim(2212, 2213)
#      24 # Plotting both the curves simultaneously
# ---> 25 plt.plot(TimeEdit, a)
#      26 plt.plot(TimeEdit, b)
#      27 plt.plot(TimeEdit, c)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
